# %%
import nltk
import os
import zipfile

# Set up custom NLTK data dir
nltk_data_dir = "/kaggle/working/nltk_data"
corpora_path = os.path.join(nltk_data_dir, "corpora")
os.makedirs(corpora_path, exist_ok=True)
nltk.data.path.append(nltk_data_dir)

# Download
nltk.download("wordnet", download_dir=nltk_data_dir)
nltk.download("omw-1.4", download_dir=nltk_data_dir)

# Unzip (Kaggle downloads zip instead of extracting)
def unzip_corpus(zip_path, extract_to):
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)

unzip_corpus(f"{corpora_path}/wordnet.zip", corpora_path)
unzip_corpus(f"{corpora_path}/omw-1.4.zip", corpora_path)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /kaggle/working/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import os
import random
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from PIL import Image

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Install dependencies (if not already installed)
# !pip install nltk rouge-score transformers --quiet

import nltk
nltk.download('wordnet')
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer

from transformers import ViTModel, AutoTokenizer, pipeline, GPT2Model
from transformers import AutoProcessor, AutoModelForVision2Seq
from transformers.image_utils import load_image
# Out:
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
'''
Samw as Part-A
'''
class CustomImageCaptionDataset(Dataset):
    def __init__(self, csv_path, images_folder, transform=None, tokenizer=None, max_length=30):
        self.df = pd.read_csv(csv_path)
        self.images_folder = images_folder
        self.transform = transform
        self.tokenizer = tokenizer
        self.max_length = max_length

        if 'filename' not in self.df.columns or 'caption' not in self.df.columns:
            raise ValueError("CSV must have 'filename' and 'caption' columns.")

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        filename = row['filename']
        caption = row['caption']
        image_path = os.path.join(self.images_folder, filename)
        image = Image.open(image_path).convert("RGB")

        if self.transform:
            image = self.transform(image)

        if self.tokenizer:
            tokens = self.tokenizer.encode(caption, truncation=True, max_length=self.max_length, padding='max_length')
            tokens = torch.tensor(tokens)
        else:
            tokens = caption

        return image, tokens, caption

# %%
'''
This function randomly blacks out a given percentage of 16×16 patches in an image. It works by:
Dividing the image into a grid of 16×16 patches
Randomly selecting patches to mask (based on the percentage input)
Setting selected patches to black (zero values)
Returning the partially occluded image
Useful for testing model robustness to missing visual data.
'''

def occlude_image(image: np.array, mask_percentage: int) -> np.array:
    img = image.copy()
    H, W, C = img.shape
    patch_size = 16
    num_patches_h = H // patch_size
    num_patches_w = W // patch_size

    total_patches = num_patches_h * num_patches_w
    num_to_mask = int(total_patches * (mask_percentage / 100.0))

    patch_indices = [(i, j) for i in range(num_patches_h) for j in range(num_patches_w)]
    random.shuffle(patch_indices)
    mask_indices = patch_indices[:num_to_mask]

    for (i, j) in mask_indices:
        y1 = i * patch_size
        y2 = y1 + patch_size
        x1 = j * patch_size
        x2 = x1 + patch_size
        img[y1:y2, x1:x2, :] = 0  # black out patch

    return img

# %%
'''
This cell evaluates the model on test set 
'''

device = 'cuda' if torch.cuda.is_available() else 'cpu'

def evaluate_on_occluded_images(model, dataloader, device, occlusion_levels, tokenizer):
    model.to(device)
    model.eval()

    results = {}
    details_list = []  # To store per-sample details for analysis

    for level in occlusion_levels:
        print(f"Evaluating occlusion level: {level}")
        bleu_scores = []
        meteor_scores_ = []
        rouge_l_scores = []
        scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)

        with torch.no_grad():
            batch_count = 0
            for images, captions, raw_captions in dataloader:
                batch_count += 1

                # Occlude each image in the batch and collect occluded images
                occluded_images = []
                for img_tensor in images:
                    # 1) unnormalize
                    np_img = img_tensor.cpu().numpy()
                    np_img = np.transpose(np_img, (1, 2, 0))
                    np_img = (np_img * 0.5) + 0.5
                    np_img = np.clip(np_img, 0, 1)
                    np_img = (np_img * 255).astype(np.uint8)

                    # 2) occlude
                    occluded_np = occlude_image(np_img, level)

                    # 3) re-normalize
                    occluded_np = occluded_np.astype(np.float32) / 255.0
                    occluded_np = np.clip(occluded_np, 0, 1)
                    occluded_np = (occluded_np - 0.5) / 0.5
                    occluded_tensor = torch.from_numpy(np.transpose(occluded_np, (2, 0, 1)))

                    occluded_images.append(occluded_tensor)

                occluded_batch = torch.stack(occluded_images).to(device)
                captions = captions.to(device)

                # Generate predictions (greedy decoding)
                batch_size = occluded_batch.size(0)

                start_token = tokenizer.eos_token_id
                generated = torch.full((batch_size, 1), start_token, dtype=torch.long).to(device)

                for _ in range(model.max_seq_length - 1):
                    outputs = model(occluded_batch, generated)
                    next_token = outputs[:, -1, :].argmax(dim=-1).unsqueeze(1)
                    generated = torch.cat([generated, next_token], dim=1)

                # Compute metrics and save details for analysis
                for i in range(batch_size):
                    pred_caption = tokenizer.decode(generated[i], skip_special_tokens=True)
                    ref_caption = raw_captions[i]
                    smooth = SmoothingFunction().method1
                    bleu = sentence_bleu([ref_caption.split()], pred_caption.split(), smoothing_function=smooth)
                    m_score = meteor_score([ref_caption.split()], pred_caption.split())
                    r_score = scorer.score(ref_caption, pred_caption)['rougeL'].fmeasure

                    bleu_scores.append(bleu)
                    meteor_scores_.append(m_score)
                    rouge_l_scores.append(r_score)
                    details_list.append({
                        "occlusion_level": level,
                        "original_caption": ref_caption,
                        "generated_caption": pred_caption,
                        "BLEU": bleu,
                        "METEOR": m_score,
                        "ROUGE-L": r_score,
                        "occluded_image": occluded_images[i]  # store corresponding occluded image tensor
                    })

                print(f"  Processed batch {batch_count}/{len(dataloader)} at occlusion level {level}")

        results[level] = {
            "BLEU": np.mean(bleu_scores),
            "METEOR": np.mean(meteor_scores_),
            "ROUGE-L": np.mean(rouge_l_scores)
        }

        print(f"Completed evaluation for occlusion level {level}\n")

    results["details"] = details_list
    return results

# %%
'''
Same as Part-A
'''
class ImageCaptionModel(nn.Module):
    def __init__(self,
                 encoder_model_name="google/vit-base-patch16-224",
                 decoder_model_name="gpt2",
                 max_seq_length=50):
        super(ImageCaptionModel, self).__init__()
        self.encoder = ViTModel.from_pretrained(encoder_model_name)
        encoder_hidden_dim = self.encoder.config.hidden_size
        self.decoder = GPT2Model.from_pretrained(decoder_model_name)
        decoder_embed_dim = self.decoder.config.n_embd
        self.encoder_proj = nn.Linear(encoder_hidden_dim, decoder_embed_dim)
        self.vocab_size = self.decoder.config.vocab_size
        self.fc_out = nn.Linear(decoder_embed_dim, self.vocab_size)

        self.max_seq_length = max_seq_length

    def forward(self, images, captions):
        batch_size = images.size(0)
        encoder_outputs = self.encoder(images).last_hidden_state
        memory = self.encoder_proj(encoder_outputs)
        num_image_tokens = memory.size(1)
        caption_embeddings = self.decoder.wte(captions)
        inputs_embeds = torch.cat([memory, caption_embeddings], dim=1)
        seq_length = captions.size(1)
        position_ids = torch.arange(0, num_image_tokens + seq_length, dtype=torch.long, device=captions.device).unsqueeze(0).repeat(batch_size, 1)
        decoder_outputs = self.decoder(inputs_embeds=inputs_embeds, position_ids=position_ids).last_hidden_state
        caption_outputs = decoder_outputs[:, num_image_tokens:, :]
        logits = self.fc_out(caption_outputs)

        return logits

# %%
'''
Same as Part-A
'''
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def zero_shot_captioning(image_path: str,
                         model_name: str = "HuggingFaceTB/SmolVLM-256M-Instruct",
                         token: str = None) -> str:
    processor = AutoProcessor.from_pretrained(model_name, token=token)
    model = AutoModelForVision2Seq.from_pretrained(model_name,torch_dtype=torch.bfloat16,_attn_implementation="eager",token=token).to(DEVICE)
    image = Image.open(image_path).convert("RGB")

    # Define the prompt using the chat template
    messages = [
        {"role": "user",
         "content": [
              {"type": "image"},
              {"type": "text", "text": "Describe this image."}
             ]
        }
    ]
    text = processor.apply_chat_template(messages, add_generation_prompt=True)
    inputs = processor(text=[text.strip()], images=[image], return_tensors="pt", padding=True).to(DEVICE)

    # Generate caption
    generated_ids = model.generate(**inputs, max_new_tokens=50)
    generated_ids = generated_ids[:, inputs['input_ids'].shape[1]:]
    caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return caption

# %%
'''
This cell evaluates the model on test set using SMOLvlm model 
'''

def evaluate_zero_shot_occluded(test_dataset, test_folder,
                                model_name: str = "HuggingFaceTB/SmolVLM-256M-Instruct",
                                token: str = None,
                                occlusion_levels=[0, 10, 50, 80]) -> dict:
    DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    # Load processor and model once.
    print(f"Loading zero-shot SmolVLM model: {model_name} with attn_implementation='eager' ...")
    processor = AutoProcessor.from_pretrained(model_name, token=token)
    model = AutoModelForVision2Seq.from_pretrained(
        model_name,
        torch_dtype=torch.bfloat16,
        _attn_implementation="eager",
        token=token
    ).to(DEVICE)
    model.eval()
    print("Model loaded.\n")

    results = {}
    details_list = []
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    num_samples = len(test_dataset)

    for level in occlusion_levels:
        print(f"Evaluating occlusion level: {level}%")
        bleu_scores = []
        meteor_scores = []
        rouge_l_scores = []

        for idx in range(num_samples):
            # Retrieve sample info from the dataset
            filename = test_dataset.df.iloc[idx]['filename']
            ref_caption = test_dataset.df.iloc[idx]['caption']
            image_path = os.path.join(test_folder, filename)

            # Load image and apply occlusion
            image = Image.open(image_path).convert("RGB")
            image_np = np.array(image)
            occluded_np = occlude_image(image_np, level)
            occluded_image = Image.fromarray(occluded_np)

            # Generate caption using zero-shot approach with chat prompt
            messages = [
                {"role": "user",
                 "content": [
                      {"type": "image"},
                      {"type": "text", "text": "Describe this image."}
                     ]
                }
            ]
            text = processor.apply_chat_template(messages, add_generation_prompt=True)
            inputs = processor(text=[text.strip()], images=[occluded_image], return_tensors="pt", padding=True).to(DEVICE)

            # Generate caption
            generated_ids = model.generate(**inputs, max_new_tokens=50)
            generated_ids = generated_ids[:, inputs['input_ids'].shape[1]:]
            generated_caption = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
            # Compute metrics (tokenized by whitespace)
            smooth = SmoothingFunction().method1
            bleu = sentence_bleu([ref_caption.split()], generated_caption.split(), smoothing_function=smooth)
            meteor = meteor_score([ref_caption.split()], generated_caption.split())
            r_score = scorer.score(ref_caption, generated_caption)['rougeL'].fmeasure

            bleu_scores.append(bleu)
            meteor_scores.append(meteor)
            rouge_l_scores.append(r_score)

            details_list.append({
                "occlusion_level": level,
                "filename": filename,
                "original_caption": ref_caption,
                "generated_caption": generated_caption,
                "BLEU": bleu,
                "METEOR": meteor,
                "ROUGE-L": r_score
            })

            print(f"[{idx+1}/{num_samples}] Occlusion {level}% => BLEU: {bleu:.4f}, "
                  f"METEOR: {meteor:.4f}, ROUGE-L: {r_score:.4f}")

        avg_bleu = np.mean(bleu_scores)
        avg_meteor = np.mean(meteor_scores)
        avg_rouge = np.mean(rouge_l_scores)
        results[level] = {"BLEU": avg_bleu, "METEOR": avg_meteor, "ROUGE-L": avg_rouge}
        print(f"Completed evaluation for occlusion level {level}%")
        print(f"Average Scores -> BLEU: {avg_bleu:.4f}, METEOR: {avg_meteor:.4f}, ROUGE-L: {avg_rouge:.4f}\n")

    results["details"] = details_list
    return results

# %%
'''
main function from which all functions are called 
'''
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("Using device:", device)

# Define dataset paths (adjust if necessary)
dataset_root = "custom_captions_dataset"
test_csv = os.path.join(dataset_root, "test.csv")
test_folder = os.path.join(dataset_root, "test")

# Define transforms (must match training preprocessing)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# Initialize tokenizer (using GPT-2 tokenizer)
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token

test_dataset = CustomImageCaptionDataset(csv_path=test_csv, images_folder=test_folder,
                                           transform=transform, tokenizer=tokenizer, max_length=30)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False)

model = ImageCaptionModel()
model.to(device)

# Define optimizer and loss (for completeness; not used here since model is pre-trained)
optimizer = optim.Adam(model.parameters(), lr=1e-4)
criterion = nn.CrossEntropyLoss(ignore_index=tokenizer.pad_token_id)

weights_path = "model_weights.pt"

# Check if saved weights exist
if os.path.exists(weights_path):
    model.load_state_dict(torch.load(weights_path, map_location=device))
    print(f"Loaded model weights from {weights_path}")
else:
    print("No saved weights found. Training from scratch.")
# Out:
# Using device: cuda
# Some weights of the model checkpoint at google/vit-base-patch16-224 were not used when initializing ViTModel: ['classifier.weight', 'classifier.bias']
# - This IS expected if you are initializing ViTModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['vit.pooler.dense.bias', 'vit.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loaded model weights from model_weights.pt

# %%
## Custom starts here
# Evaluate on occluded images including baseline (0% occlusion)
occlusion_levels = [0, 10, 50, 80]
occlusion_results = evaluate_on_occluded_images(model, test_loader, device, occlusion_levels, tokenizer)

baseline = occlusion_results[0]
print("Baseline (no occlusion) metrics:", baseline)

# Compute changes relative to baseline for occlusion levels 10, 50, and 80
changes = {}
for lvl in [10, 50, 80]:
    changes[lvl] = {
        "BLEU_change": occlusion_results[lvl]["BLEU"] - baseline["BLEU"],
        "METEOR_change": occlusion_results[lvl]["METEOR"] - baseline["METEOR"],
        "ROUGE-L_change": occlusion_results[lvl]["ROUGE-L"] - baseline["ROUGE-L"]
    }

print("\nOcclusion Evaluation Metrics and Changes:")
for lvl in [10, 50, 80]:
    print(f"Occlusion {lvl}% => Metrics: {occlusion_results[lvl]}, Changes: {changes[lvl]}")
# Out:
# Evaluating occlusion level: 0
#   Processed batch 1/58 at occlusion level 0
#   Processed batch 2/58 at occlusion level 0
#   Processed batch 3/58 at occlusion level 0
#   Processed batch 4/58 at occlusion level 0
#   Processed batch 5/58 at occlusion level 0
#   Processed batch 6/58 at occlusion level 0
#   Processed batch 7/58 at occlusion level 0
#   Processed batch 8/58 at occlusion level 0
#   Processed batch 9/58 at occlusion level 0
#   Processed batch 10/58 at occlusion level 0
#   Processed batch 11/58 at occlusion level 0
#   Processed batch 12/58 at occlusion level 0
#   Processed batch 13/58 at occlusion level 0
#   Processed batch 14/58 at occlusion level 0
#   Processed batch 15/58 at occlusion level 0
#   Processed batch 16/58 at occlusion level 0
#   Processed batch 17/58 at occlusion level 0
#   Processed batch 18/58 at occlusion level 0
#   Processed batch 19/58 at occlusion level 0
#   Processed batch 20/58 at occlusion level 0
#   Processed batch 21/58 at occlusion level 0
#   Processed batch 22/58 at occlusion level 0
#   Processed batch 23/58 at occlusion level 0
#   Processed batch 24/58 at occlusion level 0
#   Processed batch 25/58 at occlusion level 0
#   Processed batch 26/58 at occlusion level 0
#   Processed batch 27/58 at occlusion level 0
#   Processed batch 28/58 at occlusion level 0
#   Processed batch 29/58 at occlusion level 0
#   Processed batch 30/58 at occlusion level 0
#   Processed batch 31/58 at occlusion level 0
#   Processed batch 32/58 at occlusion level 0
#   Processed batch 33/58 at occlusion level 0
#   Processed batch 34/58 at occlusion level 0
#   Processed batch 35/58 at occlusion level 0
#   Processed batch 36/58 at occlusion level 0
#   Processed batch 37/58 at occlusion level 0
#   Processed batch 38/58 at occlusion level 0
#   Processed batch 39/58 at occlusion level 0
#   Processed batch 40/58 at occlusion level 0
#   Processed batch 41/58 at occlusion level 0
#   Processed batch 42/58 at occlusion level 0
#   Processed batch 43/58 at occlusion level 0
#   Processed batch 44/58 at occlusion level 0
#   Processed batch 45/58 at occlusion level 0
#   Processed batch 46/58 at occlusion level 0
#   Processed batch 47/58 at occlusion level 0
#   Processed batch 48/58 at occlusion level 0
#   Processed batch 49/58 at occlusion level 0
#   Processed batch 50/58 at occlusion level 0
#   Processed batch 51/58 at occlusion level 0
#   Processed batch 52/58 at occlusion level 0
#   Processed batch 53/58 at occlusion level 0
#   Processed batch 54/58 at occlusion level 0
#   Processed batch 55/58 at occlusion level 0
#   Processed batch 56/58 at occlusion level 0
#   Processed batch 57/58 at occlusion level 0
#   Processed batch 58/58 at occlusion level 0
# Completed evaluation for occlusion level 0
#
# Evaluating occlusion level: 10
#   Processed batch 1/58 at occlusion level 10
#   Processed batch 2/58 at occlusion level 10
#   Processed batch 3/58 at occlusion level 10
#   Processed batch 4/58 at occlusion level 10
#   Processed batch 5/58 at occlusion level 10
#   Processed batch 6/58 at occlusion level 10
#   Processed batch 7/58 at occlusion level 10
#   Processed batch 8/58 at occlusion level 10
#   Processed batch 9/58 at occlusion level 10
#   Processed batch 10/58 at occlusion level 10
#   Processed batch 11/58 at occlusion level 10
#   Processed batch 12/58 at occlusion level 10
#   Processed batch 13/58 at occlusion level 10
#   Processed batch 14/58 at occlusion level 10
#   Processed batch 15/58 at occlusion level 10
#   Processed batch 16/58 at occlusion level 10
#   Processed batch 17/58 at occlusion level 10
#   Processed batch 18/58 at occlusion level 10
#   Processed batch 19/58 at occlusion level 10
#   Processed batch 20/58 at occlusion level 10
#   Processed batch 21/58 at occlusion level 10
#   Processed batch 22/58 at occlusion level 10
#   Processed batch 23/58 at occlusion level 10
#   Processed batch 24/58 at occlusion level 10
#   Processed batch 25/58 at occlusion level 10
#   Processed batch 26/58 at occlusion level 10
#   Processed batch 27/58 at occlusion level 10
#   Processed batch 28/58 at occlusion level 10
#   Processed batch 29/58 at occlusion level 10
#   Processed batch 30/58 at occlusion level 10
#   Processed batch 31/58 at occlusion level 10
#   Processed batch 32/58 at occlusion level 10
#   Processed batch 33/58 at occlusion level 10
#   Processed batch 34/58 at occlusion level 10
#   Processed batch 35/58 at occlusion level 10
#   Processed batch 36/58 at occlusion level 10
#   Processed batch 37/58 at occlusion level 10
#   Processed batch 38/58 at occlusion level 10
#   Processed batch 39/58 at occlusion level 10
#   Processed batch 40/58 at occlusion level 10
#   Processed batch 41/58 at occlusion level 10
#   Processed batch 42/58 at occlusion level 10
#   Processed batch 43/58 at occlusion level 10
#   Processed batch 44/58 at occlusion level 10
#   Processed batch 45/58 at occlusion level 10
#   Processed batch 46/58 at occlusion level 10
#   Processed batch 47/58 at occlusion level 10
#   Processed batch 48/58 at occlusion level 10
#   Processed batch 49/58 at occlusion level 10
#   Processed batch 50/58 at occlusion level 10
#   Processed batch 51/58 at occlusion level 10
#   Processed batch 52/58 at occlusion level 10
#   Processed batch 53/58 at occlusion level 10
#   Processed batch 54/58 at occlusion level 10
#   Processed batch 55/58 at occlusion level 10
#   Processed batch 56/58 at occlusion level 10
#   Processed batch 57/58 at occlusion level 10
#   Processed batch 58/58 at occlusion level 10
# Completed evaluation for occlusion level 10
#
# Evaluating occlusion level: 50
#   Processed batch 1/58 at occlusion level 50
#   Processed batch 2/58 at occlusion level 50
#   Processed batch 3/58 at occlusion level 50
#   Processed batch 4/58 at occlusion level 50
#   Processed batch 5/58 at occlusion level 50
#   Processed batch 6/58 at occlusion level 50
#   Processed batch 7/58 at occlusion level 50
#   Processed batch 8/58 at occlusion level 50
#   Processed batch 9/58 at occlusion level 50
#   Processed batch 10/58 at occlusion level 50
#   Processed batch 11/58 at occlusion level 50
#   Processed batch 12/58 at occlusion level 50
#   Processed batch 13/58 at occlusion level 50
#   Processed batch 14/58 at occlusion level 50
#   Processed batch 15/58 at occlusion level 50
#   Processed batch 16/58 at occlusion level 50
#   Processed batch 17/58 at occlusion level 50
#   Processed batch 18/58 at occlusion level 50
#   Processed batch 19/58 at occlusion level 50
#   Processed batch 20/58 at occlusion level 50
#   Processed batch 21/58 at occlusion level 50
#   Processed batch 22/58 at occlusion level 50
#   Processed batch 23/58 at occlusion level 50
#   Processed batch 24/58 at occlusion level 50
#   Processed batch 25/58 at occlusion level 50
#   Processed batch 26/58 at occlusion level 50
#   Processed batch 27/58 at occlusion level 50
#   Processed batch 28/58 at occlusion level 50
#   Processed batch 29/58 at occlusion level 50
#   Processed batch 30/58 at occlusion level 50
#   Processed batch 31/58 at occlusion level 50
#   Processed batch 32/58 at occlusion level 50
#   Processed batch 33/58 at occlusion level 50
#   Processed batch 34/58 at occlusion level 50
#   Processed batch 35/58 at occlusion level 50
#   Processed batch 36/58 at occlusion level 50
#   Processed batch 37/58 at occlusion level 50
#   Processed batch 38/58 at occlusion level 50
#   Processed batch 39/58 at occlusion level 50
#   Processed batch 40/58 at occlusion level 50
#   Processed batch 41/58 at occlusion level 50
#   Processed batch 42/58 at occlusion level 50
#   Processed batch 43/58 at occlusion level 50
#   Processed batch 44/58 at occlusion level 50
#   Processed batch 45/58 at occlusion level 50
#   Processed batch 46/58 at occlusion level 50
#   Processed batch 47/58 at occlusion level 50
#   Processed batch 48/58 at occlusion level 50
#   Processed batch 49/58 at occlusion level 50
#   Processed batch 50/58 at occlusion level 50
#   Processed batch 51/58 at occlusion level 50
#   Processed batch 52/58 at occlusion level 50
#   Processed batch 53/58 at occlusion level 50
#   Processed batch 54/58 at occlusion level 50
#   Processed batch 55/58 at occlusion level 50
#   Processed batch 56/58 at occlusion level 50
#   Processed batch 57/58 at occlusion level 50
#   Processed batch 58/58 at occlusion level 50
# Completed evaluation for occlusion level 50
#
# Evaluating occlusion level: 80
#   Processed batch 1/58 at occlusion level 80
#   Processed batch 2/58 at occlusion level 80
#   Processed batch 3/58 at occlusion level 80
#   Processed batch 4/58 at occlusion level 80
#   Processed batch 5/58 at occlusion level 80
#   Processed batch 6/58 at occlusion level 80
#   Processed batch 7/58 at occlusion level 80
#   Processed batch 8/58 at occlusion level 80
#   Processed batch 9/58 at occlusion level 80
#   Processed batch 10/58 at occlusion level 80
#   Processed batch 11/58 at occlusion level 80
#   Processed batch 12/58 at occlusion level 80
#   Processed batch 13/58 at occlusion level 80
#   Processed batch 14/58 at occlusion level 80
#   Processed batch 15/58 at occlusion level 80
#   Processed batch 16/58 at occlusion level 80
#   Processed batch 17/58 at occlusion level 80
#   Processed batch 18/58 at occlusion level 80
#   Processed batch 19/58 at occlusion level 80
#   Processed batch 20/58 at occlusion level 80
#   Processed batch 21/58 at occlusion level 80
#   Processed batch 22/58 at occlusion level 80
#   Processed batch 23/58 at occlusion level 80
#   Processed batch 24/58 at occlusion level 80
#   Processed batch 25/58 at occlusion level 80
#   Processed batch 26/58 at occlusion level 80
#   Processed batch 27/58 at occlusion level 80
#   Processed batch 28/58 at occlusion level 80
#   Processed batch 29/58 at occlusion level 80
#   Processed batch 30/58 at occlusion level 80
#   Processed batch 31/58 at occlusion level 80
#   Processed batch 32/58 at occlusion level 80
#   Processed batch 33/58 at occlusion level 80
#   Processed batch 34/58 at occlusion level 80
#   Processed batch 35/58 at occlusion level 80
#   Processed batch 36/58 at occlusion level 80
#   Processed batch 37/58 at occlusion level 80
#   Processed batch 38/58 at occlusion level 80
#   Processed batch 39/58 at occlusion level 80
#   Processed batch 40/58 at occlusion level 80
#   Processed batch 41/58 at occlusion level 80
#   Processed batch 42/58 at occlusion level 80
#   Processed batch 43/58 at occlusion level 80
#   Processed batch 44/58 at occlusion level 80
#   Processed batch 45/58 at occlusion level 80
#   Processed batch 46/58 at occlusion level 80
#   Processed batch 47/58 at occlusion level 80
#   Processed batch 48/58 at occlusion level 80
#   Processed batch 49/58 at occlusion level 80
#   Processed batch 50/58 at occlusion level 80
#   Processed batch 51/58 at occlusion level 80
#   Processed batch 52/58 at occlusion level 80
#   Processed batch 53/58 at occlusion level 80
#   Processed batch 54/58 at occlusion level 80
#   Processed batch 55/58 at occlusion level 80
#   Processed batch 56/58 at occlusion level 80
#   Processed batch 57/58 at occlusion level 80
#   Processed batch 58/58 at occlusion level 80
# Completed evaluation for occlusion level 80
#
# Baseline (no occlusion) metrics: {'BLEU': 0.03395502098408148, 'METEOR': 0.20230582695255964, 'ROUGE-L': 0.2635865418635649}
#
# Occlusion Evaluation Metrics and Changes:
# Occlusion 10% => Metrics: {'BLEU': 0.033891303472409304, 'METEOR': 0.20560526436569176, 'ROUGE-L': 0.2653033810032318}, Changes: {'BLEU_change': -6.371751167217471e-05, 'METEOR_change': 0.003299437413132128, 'ROUGE-L_change': 0.0017168391396669147}
# Occlusion 50% => Metrics: {'BLEU': 0.028987158461589814, 'METEOR': 0.19674601265964933, 'ROUGE-L': 0.2590957782616857}, Changes: {'BLEU_change': -0.0049678625224916645, 'METEOR_change': -0.005559814292910303, 'ROUGE-L_change': -0.004490763601879166}
# Occlusion 80% => Metrics: {'BLEU': 0.0214678840460562, 'METEOR': 0.1793359533633179, 'ROUGE-L': 0.2386966071064507}, Changes: {'BLEU_change': -0.012487136938025278, 'METEOR_change': -0.02296987358924174, 'ROUGE-L_change': -0.024889934757114207}

# %%
keys = ["occlusion_level", "original_caption", "generated_caption"]
with open("occlusion_details_custom.csv", "w", newline="") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=keys)
    writer.writeheader()
    details = occlusion_results["details"]
    for detail in details:
        writer.writerow({k: detail[k] for k in keys})
print("Saved occlusion details to occlusion_details_custom.csv")
# Out:
# Saved occlusion details to occlusion_details_custom.csv

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
# Define dataset paths (adjust if necessary)
dataset_root = "/kaggle/input/captioning-dataset/custom_captions_dataset"
test_csv = os.path.join(dataset_root, "test.csv")
test_folder = os.path.join(dataset_root, "test")

# Define transforms (must match training preprocessing)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
])

# Initialize tokenizer (using GPT-2 tokenizer)
tokenizer = AutoTokenizer.from_pretrained("gpt2")
tokenizer.pad_token = tokenizer.eos_token  # set pad token

test_dataset = CustomImageCaptionDataset(csv_path=test_csv, images_folder=test_folder,
                                           transform=transform, tokenizer=tokenizer, max_length=30)

## SmolVLM starts here
occlusion_levels = [0, 10, 50, 80]
test_metrics_zero_shot = evaluate_zero_shot_occluded(
    test_dataset, test_folder,
    model_name="HuggingFaceTB/SmolVLM-256M-Instruct",
    token=None,
    occlusion_levels=occlusion_levels
)


baseline = test_metrics_zero_shot[0]
print("Baseline (no occlusion) metrics:", baseline)

changes = {}
for lvl in [10, 50, 80]:
    changes[lvl] = {
        "BLEU_change": test_metrics_zero_shot[lvl]["BLEU"] - baseline["BLEU"],
        "METEOR_change": test_metrics_zero_shot[lvl]["METEOR"] - baseline["METEOR"],
        "ROUGE-L_change": test_metrics_zero_shot[lvl]["ROUGE-L"] - baseline["ROUGE-L"]
    }

print("\nOcclusion Evaluation Metrics and Changes:")
for lvl in [10, 50, 80]:
    print(f"Occlusion {lvl}% => Metrics: {test_metrics_zero_shot[lvl]}, Changes: {changes[lvl]}")
# Out:
# Loading zero-shot SmolVLM model: HuggingFaceTB/SmolVLM-256M-Instruct with attn_implementation='eager' ...
# Some kwargs in processor config are unused and will not have any effect: image_seq_len.
# Model loaded.
#
# Evaluating occlusion level: 0%
# [1/928] Occlusion 0% => BLEU: 0.0129, METEOR: 0
928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.1147, ROUGE-L: 0.1622
# [725/928] Occlusion 80% => BLEU: 0.0086, METEOR: 0.1227, ROUGE-L: 0.1495
# [726/928] Occlusion 80% => BLEU: 0.0105, METEOR: 0.1662, ROUGE-L: 0.1961
# [727/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0808, ROUGE-L: 0.1468
# [728/928] Occlusion 80% => BLEU: 0.0070, METEOR: 0.1155, ROUGE-L: 0.1760
# [729/928] Occlusion 80% => BLEU: 0.0390, METEOR: 0.1433, ROUGE-L: 0.1333
# [730/928] Occlusion 80% => BLEU: 0.0065, METEOR: 0.0921, ROUGE-L: 0.1593
# [731/928] Occlusion 80% => BLEU: 0.0031, METEOR: 0.0583, ROUGE-L: 0.1290
# [732/928] Occlusion 80% => BLEU: 0.0049, METEOR: 0.1190, ROUGE-L: 0.1455
# [733/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.1126, ROUGE-L: 0.1579
# [734/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.0907, ROUGE-L: 0.1504
# [735/928] Occlusion 80% => BLEU: 0.0225, METEOR: 0.1739, ROUGE-L: 0.1495
# [736/928] Occlusion 80% => BLEU: 0.0105, METEOR: 0.1167, ROUGE-L: 0.1584
# [737/928] Occlusion 80% => BLEU: 0.0008, METEOR: 0.0593, ROUGE-L: 0.1587
# [738/928] Occlusion 80% => BLEU: 0.0023, METEOR: 0.0732, ROUGE-L: 0.1618
# [739/928] Occlusion 80% => BLEU: 0.0076, METEOR: 0.1061, ROUGE-L: 0.1667
# [740/928] Occlusion 80% => BLEU: 0.0075, METEOR: 0.1050, ROUGE-L: 0.1636
# [741/928] Occlusion 80% => BLEU: 0.0576, METEOR: 0.1443, ROUGE-L: 0.2667
# [742/928] Occlusion 80% => BLEU: 0.0086, METEOR: 0.1751, ROUGE-L: 0.2087
# [743/928] Occlusion 80% => BLEU: 0.0042, METEOR: 0.0879, ROUGE-L: 0.1308
# [744/928] Occlusion 80% => BLEU: 0.0062, METEOR: 0.0850, ROUGE-L: 0.1587
# [745/928] Occlusion 80% => BLEU: 0.0079, METEOR: 0.1218, ROUGE-L: 0.1359
# [746/928] Occlusion 80% => BLEU: 0.0029, METEOR: 0.0890, ROUGE-L: 0.1294
# [747/928] Occlusion 80% => BLEU: 0.0060, METEOR: 0.0927, ROUGE-L: 0.1972
# [748/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.0748, ROUGE-L: 0.1321
# [749/928] Occlusion 80% => BLEU: 0.0079, METEOR: 0.0908, ROUGE-L: 0.1154
# [750/928] Occlusion 80% => BLEU: 0.0070, METEOR: 0.1155, ROUGE-L: 0.1724
# [751/928] Occlusion 80% => BLEU: 0.0043, METEOR: 0.1027, ROUGE-L: 0.2056
# [752/928] Occlusion 80% => BLEU: 0.0022, METEOR: 0.0720, ROUGE-L: 0.1615
# [753/928] Occlusion 80% => BLEU: 0.0076, METEOR: 0.0894, ROUGE-L: 0.1649
# [754/928] Occlusion 80% => BLEU: 0.0081, METEOR: 0.1276, ROUGE-L: 0.1565
# [755/928] Occlusion 80% => BLEU: 0.0031, METEOR: 0.0903, ROUGE-L: 0.1437
# [756/928] Occlusion 80% => BLEU: 0.0041, METEOR: 0.0969, ROUGE-L: 0.1786
# [757/928] Occlusion 80% => BLEU: 0.0041, METEOR: 0.0942, ROUGE-L: 0.1565
# [758/928] Occlusion 80% => BLEU: 0.0153, METEOR: 0.1482, ROUGE-L: 0.1967
# [759/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.0721, ROUGE-L: 0.1550
# [760/928] Occlusion 80% => BLEU: 0.0070, METEOR: 0.1195, ROUGE-L: 0.1495
# [761/928] Occlusion 80% => BLEU: 0.0042, METEOR: 0.1195, ROUGE-L: 0.1667
# [762/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.1142, ROUGE-L: 0.1835
# [763/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0659, ROUGE-L: 0.1197
# [764/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.1041, ROUGE-L: 0.1931
# [765/928] Occlusion 80% => BLEU: 0.0019, METEOR: 0.0782, ROUGE-L: 0.1399
# [766/928] Occlusion 80% => BLEU: 0.0058, METEOR: 0.0890, ROUGE-L: 0.1374
# [767/928] Occlusion 80% => BLEU: 0.0057, METEOR: 0.1128, ROUGE-L: 0.2308
# [768/928] Occlusion 80% => BLEU: 0.0104, METEOR: 0.1276, ROUGE-L: 0.1682
# [769/928] Occlusion 80% => BLEU: 0.0088, METEOR: 0.1473, ROUGE-L: 0.1869
# [770/928] Occlusion 80% => BLEU: 0.0076, METEOR: 0.0943, ROUGE-L: 0.2037
# [771/928] Occlusion 80% => BLEU: 0.0041, METEOR: 0.0997, ROUGE-L: 0.1186
# [772/928] Occlusion 80% => BLEU: 0.0096, METEOR: 0.1113, ROUGE-L: 0.1754
# [773/928] Occlusion 80% => BLEU: 0.0087, METEOR: 0.0929, ROUGE-L: 0.1538
# [774/928] Occlusion 80% => BLEU: 0.0053, METEOR: 0.1163, ROUGE-L: 0.1748
# [775/928] Occlusion 80% => BLEU: 0.0049, METEOR: 0.1091, ROUGE-L: 0.1667
# [776/928] Occlusion 80% => BLEU: 0.0078, METEOR: 0.0883, ROUGE-L: 0.1488
# [777/928] Occlusion 80% => BLEU: 0.0106, METEOR: 0.1201, ROUGE-L: 0.1923
# [778/928] Occlusion 80% => BLEU: 0.0072, METEOR: 0.0853, ROUGE-L: 0.1636
# [779/928] Occlusion 80% => BLEU: 0.0081, METEOR: 0.1278, ROUGE-L: 0.1552
# [780/928] Occlusion 80% => BLEU: 0.0041, METEOR: 0.0930, ROUGE-L: 0.1636
# [781/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.1182, ROUGE-L: 0.1500
# [782/928] Occlusion 80% => BLEU: 0.0044, METEOR: 0.0826, ROUGE-L: 0.1404
# [783/928] Occlusion 80% => BLEU: 0.0044, METEOR: 0.0994, ROUGE-L: 0.1441
# [784/928] Occlusion 80% => BLEU: 0.0073, METEOR: 0.1127, ROUGE-L: 0.2034
# [785/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0435, ROUGE-L: 0.1091
# [786/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.1254, ROUGE-L: 0.1651
# [787/928] Occlusion 80% => BLEU: 0.0084, METEOR: 0.0984, ROUGE-L: 0.1273
# [788/928] Occlusion 80% => BLEU: 0.0096, METEOR: 0.1161, ROUGE-L: 0.2243
# [789/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.1111, ROUGE-L: 0.1739
# [790/928] Occlusion 80% => BLEU: 0.0084, METEOR: 0.1656, ROUGE-L: 0.1754
# [791/928] Occlusion 80% => BLEU: 0.0102, METEOR: 0.1437, ROUGE-L: 0.2069
# [792/928] Occlusion 80% => BLEU: 0.0038, METEOR: 0.0735, ROUGE-L: 0.1507
# [793/928] Occlusion 80% => BLEU: 0.0078, METEOR: 0.1011, ROUGE-L: 0.1495
# [794/928] Occlusion 80% => BLEU: 0.0101, METEOR: 0.0972, ROUGE-L: 0.1495
# [795/928] Occlusion 80% => BLEU: 0.0035, METEOR: 0.0951, ROUGE-L: 0.1488
# [796/928] Occlusion 80% => BLEU: 0.0225, METEOR: 0.1882, ROUGE-L: 0.2308
# [797/928] Occlusion 80% => BLEU: 0.0051, METEOR: 0.0806, ROUGE-L: 0.1481
# [798/928] Occlusion 80% => BLEU: 0.0053, METEOR: 0.0958, ROUGE-L: 0.1748
# [799/928] Occlusion 80% => BLEU: 0.0082, METEOR: 0.1353, ROUGE-L: 0.1770
# [800/928] Occlusion 80% => BLEU: 0.0026, METEOR: 0.0676, ROUGE-L: 0.1420
# [801/928] Occlusion 80% => BLEU: 0.0044, METEOR: 0.0871, ROUGE-L: 0.1250
# [802/928] Occlusion 80% => BLEU: 0.0050, METEOR: 0.1089, ROUGE-L: 0.1818
# [803/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.1118, ROUGE-L: 0.1698
# [804/928] Occlusion 80% => BLEU: 0.0031, METEOR: 0.0782, ROUGE-L: 0.1699
# [805/928] Occlusion 80% => BLEU: 0.0076, METEOR: 0.1011, ROUGE-L: 0.1651
# [806/928] Occlusion 80% => BLEU: 0.0089, METEOR: 0.1131, ROUGE-L: 0.1869
# [807/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.0921, ROUGE-L: 0.1493
# [808/928] Occlusion 80% => BLEU: 0.0040, METEOR: 0.0854, ROUGE-L: 0.1481
# [809/928] Occlusion 80% => BLEU: 0.0032, METEOR: 0.0796, ROUGE-L: 0.1311
# [810/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.1098, ROUGE-L: 0.1538
# [811/928] Occlusion 80% => BLEU: 0.0063, METEOR: 0.0813, ROUGE-L: 0.1642
# [812/928] Occlusion 80% => BLEU: 0.0049, METEOR: 0.0909, ROUGE-L: 0.1884
# [813/928] Occlusion 80% => BLEU: 0.0096, METEOR: 0.1331, ROUGE-L: 0.1947
# [814/928] Occlusion 80% => BLEU: 0.0062, METEOR: 0.1009, ROUGE-L: 0.1849
# [815/928] Occlusion 80% => BLEU: 0.0049, METEOR: 0.0845, ROUGE-L: 0.1714
# [816/928] Occlusion 80% => BLEU: 0.0086, METEOR: 0.1256, ROUGE-L: 0.2000
# [817/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.0698, ROUGE-L: 0.1481
# [818/928] Occlusion 80% => BLEU: 0.0117, METEOR: 0.1130, ROUGE-L: 0.1359
# [819/928] Occlusion 80% => BLEU: 0.0071, METEOR: 0.1480, ROUGE-L: 0.1967
# [820/928] Occlusion 80% => BLEU: 0.0036, METEOR: 0.0588, ROUGE-L: 0.1239
# [821/928] Occlusion 80% => BLEU: 0.0085, METEOR: 0.0835, ROUGE-L: 0.1538
# [822/928] Occlusion 80% => BLEU: 0.0051, METEOR: 0.0723, ROUGE-L: 0.1224
# [823/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0914, ROUGE-L: 0.1667
# [824/928] Occlusion 80% => BLEU: 0.0050, METEOR: 0.0696, ROUGE-L: 0.1333
# [825/928] Occlusion 80% => BLEU: 0.0035, METEOR: 0.0696, ROUGE-L: 0.1167
# [826/928] Occlusion 80% => BLEU: 0.0092, METEOR: 0.1192, ROUGE-L: 0.1964
# [827/928] Occlusion 80% => BLEU: 0.0102, METEOR: 0.1294, ROUGE-L: 0.2124
# [828/928] Occlusion 80% => BLEU: 0.0053, METEOR: 0.0695, ROUGE-L: 0.1460
# [829/928] Occlusion 80% => BLEU: 0.0097, METEOR: 0.1047, ROUGE-L: 0.1724
# [830/928] Occlusion 80% => BLEU: 0.0043, METEOR: 0.1081, ROUGE-L: 0.1864
# [831/928] Occlusion 80% => BLEU: 0.0043, METEOR: 0.1143, ROUGE-L: 0.1607
# [832/928] Occlusion 80% => BLEU: 0.0162, METEOR: 0.1085, ROUGE-L: 0.1897
# [833/928] Occlusion 80% => BLEU: 0.0058, METEOR: 0.0962, ROUGE-L: 0.1440
# [834/928] Occlusion 80% => BLEU: 0.0082, METEOR: 0.1150, ROUGE-L: 0.2114
# [835/928] Occlusion 80% => BLEU: 0.0013, METEOR: 0.0589, ROUGE-L: 0.1250
# [836/928] Occlusion 80% => BLEU: 0.0015, METEOR: 0.0561, ROUGE-L: 0.1258
# [837/928] Occlusion 80% => BLEU: 0.0036, METEOR: 0.0745, ROUGE-L: 0.1639
# [838/928] Occlusion 80% => BLEU: 0.0184, METEOR: 0.1676, ROUGE-L: 0.2414
# [839/928] Occlusion 80% => BLEU: 0.0080, METEOR: 0.1298, ROUGE-L: 0.1880
# [840/928] Occlusion 80% => BLEU: 0.0065, METEOR: 0.0850, ROUGE-L: 0.1391
# [841/928] Occlusion 80% => BLEU: 0.0095, METEOR: 0.0960, ROUGE-L: 0.1569
# [842/928] Occlusion 80% => BLEU: 0.0014, METEOR: 0.0882, ROUGE-L: 0.1687
# [843/928] Occlusion 80% => BLEU: 0.0089, METEOR: 0.0893, ROUGE-L: 0.1489
# [844/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0952, ROUGE-L: 0.1964
# [845/928] Occlusion 80% => BLEU: 0.0074, METEOR: 0.0849, ROUGE-L: 0.1739
# [846/928] Occlusion 80% => BLEU: 0.0037, METEOR: 0.0904, ROUGE-L: 0.1167
# [847/928] Occlusion 80% => BLEU: 0.0068, METEOR: 0.1100, ROUGE-L: 0.1681
# [848/928] Occlusion 80% => BLEU: 0.0098, METEOR: 0.1396, ROUGE-L: 0.1782
# [849/928] Occlusion 80% => BLEU: 0.0080, METEOR: 0.0971, ROUGE-L: 0.1481
# [850/928] Occlusion 80% => BLEU: 0.0099, METEOR: 0.1242, ROUGE-L: 0.2037
# [851/928] Occlusion 80% => BLEU: 0.0165, METEOR: 0.1742, ROUGE-L: 0.1897
# [852/928] Occlusion 80% => BLEU: 0.0018, METEOR: 0.0878, ROUGE-L: 0.1307
# [853/928] Occlusion 80% => BLEU: 0.0090, METEOR: 0.0718, ROUGE-L: 0.1386
# [854/928] Occlusion 80% => BLEU: 0.0044, METEOR: 0.1301, ROUGE-L: 0.1897
# [855/928] Occlusion 80% => BLEU: 0.0095, METEOR: 0.0960, ROUGE-L: 0.1569
# [856/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0808, ROUGE-L: 0.1404
# [857/928] Occlusion 80% => BLEU: 0.0075, METEOR: 0.0982, ROUGE-L: 0.1636
# [858/928] Occlusion 80% => BLEU: 0.0019, METEOR: 0.0765, ROUGE-L: 0.1457
# [859/928] Occlusion 80% => BLEU: 0.0087, METEOR: 0.1165, ROUGE-L: 0.1714
# [860/928] Occlusion 80% => BLEU: 0.0038, METEOR: 0.0964, ROUGE-L: 0.1849
# [861/928] Occlusion 80% => BLEU: 0.0142, METEOR: 0.1623, ROUGE-L: 0.1852
# [862/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0849, ROUGE-L: 0.1373
# [863/928] Occlusion 80% => BLEU: 0.0034, METEOR: 0.0838, ROUGE-L: 0.1552
# [864/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0756, ROUGE-L: 0.1607
# [865/928] Occlusion 80% => BLEU: 0.0095, METEOR: 0.1278, ROUGE-L: 0.1770
# [866/928] Occlusion 80% => BLEU: 0.0116, METEOR: 0.1642, ROUGE-L: 0.2124
# [867/928] Occlusion 80% => BLEU: 0.0092, METEOR: 0.1349, ROUGE-L: 0.1636
# [868/928] Occlusion 80% => BLEU: 0.0037, METEOR: 0.0653, ROUGE-L: 0.1416
# [869/928] Occlusion 80% => BLEU: 0.0046, METEOR: 0.0874, ROUGE-L: 0.1651
# [870/928] Occlusion 80% => BLEU: 0.0051, METEOR: 0.1064, ROUGE-L: 0.1869
# [871/928] Occlusion 80% => BLEU: 0.0031, METEOR: 0.0949, ROUGE-L: 0.1719
# [872/928] Occlusion 80% => BLEU: 0.0069, METEOR: 0.0786, ROUGE-L: 0.1667
# [873/928] Occlusion 80% => BLEU: 0.0035, METEOR: 0.0790, ROUGE-L: 0.1250
# [874/928] Occlusion 80% => BLEU: 0.0097, METEOR: 0.1147, ROUGE-L: 0.2000
# [875/928] Occlusion 80% => BLEU: 0.0020, METEOR: 0.0690, ROUGE-L: 0.1268
# [876/928] Occlusion 80% => BLEU: 0.0088, METEOR: 0.1146, ROUGE-L: 0.1495
# [877/928] Occlusion 80% => BLEU: 0.0098, METEOR: 0.1101, ROUGE-L: 0.1770
# [878/928] Occlusion 80% => BLEU: 0.0090, METEOR: 0.1017, ROUGE-L: 0.1942
# [879/928] Occlusion 80% => BLEU: 0.0107, METEOR: 0.1953, ROUGE-L: 0.2264
# [880/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.1236, ROUGE-L: 0.1802
# [881/928] Occlusion 80% => BLEU: 0.0048, METEOR: 0.1294, ROUGE-L: 0.1852
# [882/928] Occlusion 80% => BLEU: 0.0055, METEOR: 0.0901, ROUGE-L: 0.1584
# [883/928] Occlusion 80% => BLEU: 0.0008, METEOR: 0.0515, ROUGE-L: 0.1321
# [884/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.0821, ROUGE-L: 0.1400
# [885/928] Occlusion 80% => BLEU: 0.0044, METEOR: 0.1022, ROUGE-L: 0.1667
# [886/928] Occlusion 80% => BLEU: 0.0065, METEOR: 0.1177, ROUGE-L: 0.1575
# [887/928] Occlusion 80% => BLEU: 0.0106, METEOR: 0.1541, ROUGE-L: 0.1584
# [888/928] Occlusion 80% => BLEU: 0.0066, METEOR: 0.0939, ROUGE-L: 0.1552
# [889/928] Occlusion 80% => BLEU: 0.0057, METEOR: 0.1035, ROUGE-L: 0.1440
# [890/928] Occlusion 80% => BLEU: 0.0043, METEOR: 0.0789, ROUGE-L: 0.1111
# [891/928] Occlusion 80% => BLEU: 0.0075, METEOR: 0.1421, ROUGE-L: 0.1622
# [892/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0940, ROUGE-L: 0.1273
# [893/928] Occlusion 80% => BLEU: 0.0043, METEOR: 0.0518, ROUGE-L: 0.0990
# [894/928] Occlusion 80% => BLEU: 0.0083, METEOR: 0.1053, ROUGE-L: 0.1509
# [895/928] Occlusion 80% => BLEU: 0.0077, METEOR: 0.1140, ROUGE-L: 0.1864
# [896/928] Occlusion 80% => BLEU: 0.0080, METEOR: 0.1095, ROUGE-L: 0.2051
# [897/928] Occlusion 80% => BLEU: 0.0045, METEOR: 0.0866, ROUGE-L: 0.1296
# [898/928] Occlusion 80% => BLEU: 0.0051, METEOR: 0.1029, ROUGE-L: 0.1538
# [899/928] Occlusion 80% => BLEU: 0.0104, METEOR: 0.1416, ROUGE-L: 0.1961
# [900/928] Occlusion 80% => BLEU: 0.0133, METEOR: 0.1216, ROUGE-L: 0.1746
# [901/928] Occlusion 80% => BLEU: 0.0075, METEOR: 0.0969, ROUGE-L: 0.1250
# [902/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0927, ROUGE-L: 0.1818
# [903/928] Occlusion 80% => BLEU: 0.0032, METEOR: 0.0910, ROUGE-L: 0.1724
# [904/928] Occlusion 80% => BLEU: 0.0091, METEOR: 0.1051, ROUGE-L: 0.1600
# [905/928] Occlusion 80% => BLEU: 0.0075, METEOR: 0.1525, ROUGE-L: 0.2393
# [906/928] Occlusion 80% => BLEU: 0.0039, METEOR: 0.0699, ROUGE-L: 0.1416
# [907/928] Occlusion 80% => BLEU: 0.0066, METEOR: 0.0972, ROUGE-L: 0.1500
# [908/928] Occlusion 80% => BLEU: 0.0049, METEOR: 0.0698, ROUGE-L: 0.0980
# [909/928] Occlusion 80% => BLEU: 0.0034, METEOR: 0.0931, ROUGE-L: 0.1653
# [910/928] Occlusion 80% => BLEU: 0.0050, METEOR: 0.0993, ROUGE-L: 0.1818
# [911/928] Occlusion 80% => BLEU: 0.0118, METEOR: 0.1317, ROUGE-L: 0.2136
# [912/928] Occlusion 80% => BLEU: 0.0014, METEOR: 0.0733, ROUGE-L: 0.1279
# [913/928] Occlusion 80% => BLEU: 0.0131, METEOR: 0.1905, ROUGE-L: 0.2202
# [914/928] Occlusion 80% => BLEU: 0.0052, METEOR: 0.1014, ROUGE-L: 0.1507
# [915/928] Occlusion 80% => BLEU: 0.0063, METEOR: 0.0837, ROUGE-L: 0.1538
# [916/928] Occlusion 80% => BLEU: 0.0082, METEOR: 0.1082, ROUGE-L: 0.1622
# [917/928] Occlusion 80% => BLEU: 0.0090, METEOR: 0.0774, ROUGE-L: 0.1273
# [918/928] Occlusion 80% => BLEU: 0.0034, METEOR: 0.1046, ROUGE-L: 0.1920
# [919/928] Occlusion 80% => BLEU: 0.0073, METEOR: 0.1143, ROUGE-L: 0.1880
# [920/928] Occlusion 80% => BLEU: 0.0088, METEOR: 0.1192, ROUGE-L: 0.1622
# [921/928] Occlusion 80% => BLEU: 0.0051, METEOR: 0.1349, ROUGE-L: 0.1905
# [922/928] Occlusion 80% => BLEU: 0.0107, METEOR: 0.1752, ROUGE-L: 0.1569
# [923/928] Occlusion 80% => BLEU: 0.0077, METEOR: 0.1119, ROUGE-L: 0.1897
# [924/928] Occlusion 80% => BLEU: 0.0124, METEOR: 0.1116, ROUGE-L: 0.2056
# [925/928] Occlusion 80% => BLEU: 0.0859, METEOR: 0.1270, ROUGE-L: 0.2364
# [926/928] Occlusion 80% => BLEU: 0.0047, METEOR: 0.0833, ROUGE-L: 0.1731
# [927/928] Occlusion 80% => BLEU: 0.0029, METEOR: 0.0752, ROUGE-L: 0.1575
# [928/928] Occlusion 80% => BLEU: 0.0048, METEOR: 0.1129, ROUGE-L: 0.1818
# Completed evaluation for occlusion level 80%
# Average Scores -> BLEU: 0.0082, METEOR: 0.1166, ROUGE-L: 0.1670
#
# Baseline (no occlusion) metrics: {'BLEU': 0.022590095555554916, 'METEOR': 0.17460402852155274, 'ROUGE-L': 0.2359157711264497}
#
# Occlusion Evaluation Metrics and Changes:
# Occlusion 10% => Metrics: {'BLEU': 0.022232421937017025, 'METEOR': 0.17377881106559948, 'ROUGE-L': 0.23231831502032063}, Changes: {'BLEU_change': -0.00035767361853789037, 'METEOR_change': -0.0008252174559532643, 'ROUGE-L_change': -0.0035974561061290766}
# Occlusion 50% => Metrics: {'BLEU': 0.015276985092314474, 'METEOR': 0.15029846969220426, 'ROUGE-L': 0.2044620539140021}, Changes: {'BLEU_change': -0.007313110463240442, 'METEOR_change': -0.024305558829348484, 'ROUGE-L_change': -0.03145371721244761}
# Occlusion 80% => Metrics: {'BLEU': 0.00821544358143257, 'METEOR': 0.11662987105068454, 'ROUGE-L': 0.16695379352541911}, Changes: {'BLEU_change': -0.014374651974122346, 'METEOR_change': -0.057974157470868204, 'ROUGE-L_change': -0.0689619776010306}

# %%
# Save per-sample details to a CSV file.
import csv
keys = ["occlusion_level", "original_caption", "generated_caption"]
with open("/kaggle/working/occlusion_details_SmolVLM.csv", "w", newline="",  encoding="utf-8") as csvfile:
    writer = csv.DictWriter(csvfile, fieldnames=keys)
    writer.writeheader()
    details = test_metrics_zero_shot["details"]
    for detail in details:
        writer.writerow({k: detail[k] for k in keys})
print("Saved occlusion details to occlusion_details_SmolVLM.csv")
# Out:
# Saved occlusion details to occlusion_details_SmolVLM.csv
